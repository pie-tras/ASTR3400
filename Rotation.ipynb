# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/jepo4196/py_mesa_reader')
import mesa_reader as m

path = '/home/jepo4196/astr3400/Rotation/Rotation 0.0/'
prof0_1 = m.MesaData(file_name=path+'profile1.data')
prof0_2 = m.MesaData(file_name=path+'profile2.data')
prof0_3 = m.MesaData(file_name=path+'profile3.data')
prof0_4 = m.MesaData(file_name=path+'profile4.data')
prof0_5 = m.MesaData(file_name=path+'profile5.data')
prof0_6 = m.MesaData(file_name=path+'profile6.data')
hist0   = m.MesaData(file_name=path+'history.data')

path = '/home/jepo4196/astr3400/Rotation/Rotation 0.2/'
prof2_1 = m.MesaData(file_name=path+'profile1.data')
prof2_2 = m.MesaData(file_name=path+'profile2.data')
prof2_3 = m.MesaData(file_name=path+'profile3.data')
prof2_4 = m.MesaData(file_name=path+'profile4.data')
prof2_5 = m.MesaData(file_name=path+'profile5.data')
prof2_6 = m.MesaData(file_name=path+'profile6.data')
prof2_7 = m.MesaData(file_name=path+'profile7.data')
prof2_8 = m.MesaData(file_name=path+'profile8.data')
hist2   = m.MesaData(file_name=path+'history.data')

path = '/home/jepo4196/astr3400/Rotation/Rotation 0.4/'
prof4_1 = m.MesaData(file_name=path+'profile1.data')
prof4_2 = m.MesaData(file_name=path+'profile2.data')
prof4_3 = m.MesaData(file_name=path+'profile3.data')
prof4_4 = m.MesaData(file_name=path+'profile4.data')
prof4_5 = m.MesaData(file_name=path+'profile5.data')
prof4_6 = m.MesaData(file_name=path+'profile6.data')
prof4_7 = m.MesaData(file_name=path+'profile7.data')
prof4_8 = m.MesaData(file_name=path+'profile8.data')
prof4_9 = m.MesaData(file_name=path+'profile9.data')
prof4_10 = m.MesaData(file_name=path+'profile10.data')
prof4_11 = m.MesaData(file_name=path+'profile11.data')
prof4_12 = m.MesaData(file_name=path+'profile12.data')
prof4_13 = m.MesaData(file_name=path+'profile13.data')
prof4_14 = m.MesaData(file_name=path+'profile14.data')
prof4_15 = m.MesaData(file_name=path+'profile15.data')
hist4   = m.MesaData(file_name=path+'history.data')

# %%
plt.style.use("dark_background")
fig, axs = plt.subplots(2, 3, figsize=(16, 10))
plt.subplots_adjust(hspace=.25, wspace=0.25)


axs[0,0].plot(prof0_1.data('zone'),prof0_1.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,0].plot(prof0_1.data('zone'),prof0_1.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,0].plot(prof0_1.data('zone'),prof0_1.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,0].set_ylabel('Percent of Mass')
axs[0,0].set_xlabel('Zone')
axs[0,0].set_ylim(-.05,1.05)
axs[0,0].set_xlim(np.max(prof0_1.data('zone'))+10,np.min(prof0_1.data('zone'))-10)
axs[0,0].set_title('Profile 1 Zones v Elemental Mass %')
axs[0,0].legend()

axs[0,1].plot(prof0_2.data('zone'),prof0_2.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,1].plot(prof0_2.data('zone'),prof0_2.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,1].plot(prof0_2.data('zone'),prof0_2.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,1].set_ylabel('Percent of Mass')
axs[0,1].set_xlabel('Zone')
axs[0,1].set_ylim(-.05,1.05)
axs[0,1].set_xlim(np.max(prof0_2.data('zone'))+10,np.min(prof0_2.data('zone'))-10)
axs[0,1].set_title('Profile 2 Zones v Elemental Mass %')
axs[0,1].legend()

axs[0,2].plot(prof0_3.data('zone'),prof0_3.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,2].plot(prof0_3.data('zone'),prof0_3.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,2].plot(prof0_3.data('zone'),prof0_3.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,2].set_ylabel('Percent of Mass')
axs[0,2].set_xlabel('Zone')
axs[0,2].set_ylim(-.05,1.05)
axs[0,2].set_xlim(np.max(prof0_3.data('zone'))+10,np.min(prof0_3.data('zone'))-10)
axs[0,2].set_title('Profile 3 Zones v Elemental Mass %')
axs[0,2].legend()

axs[1,0].plot(prof0_4.data('zone'),prof0_4.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,0].plot(prof0_4.data('zone'),prof0_4.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,0].plot(prof0_4.data('zone'),prof0_4.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,0].set_ylabel('Percent of Mass')
axs[1,0].set_xlabel('Zone')
axs[1,0].set_ylim(-.05,1.05)
axs[1,0].set_xlim(np.max(prof0_4.data('zone'))+10,np.min(prof0_4.data('zone'))-10)
axs[1,0].set_title('Profile 4 Zones v Elemental Mass %')
axs[1,0].legend()

axs[1,1].plot(prof0_5.data('zone'),prof0_5.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,1].plot(prof0_5.data('zone'),prof0_5.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,1].plot(prof0_5.data('zone'),prof0_5.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,1].set_ylabel('Percent of Mass')
axs[1,1].set_xlabel('Zone')
axs[1,1].set_ylim(-.05,1.05)
axs[1,1].set_xlim(np.max(prof0_5.data('zone'))+10,np.min(prof0_5.data('zone'))-10)
axs[1,1].set_title('Profile 5 Zones v Elemental Mass %')
axs[1,1].legend()

axs[1,2].plot(prof0_6.data('zone'),prof0_6.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,2].plot(prof0_6.data('zone'),prof0_6.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,2].plot(prof0_6.data('zone'),prof0_6.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,2].set_ylabel('Percent of Mass')
axs[1,2].set_xlabel('Zone')
axs[1,2].set_ylim(-.05,1.05)
axs[1,2].set_xlim(np.max(prof0_6.data('zone'))+10,np.min(prof0_6.data('zone'))-10)
axs[1,2].set_title('Profile 6 Zones v Elemental Mass %')
axs[1,2].legend()

# %%
fig, axs = plt.subplots(3, 3, figsize=(16, 10))
plt.subplots_adjust(hspace=.5, wspace=0.25)

axs[0,0].plot(prof2_1.data('zone'),prof2_1.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,0].plot(prof2_1.data('zone'),prof2_1.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,0].plot(prof2_1.data('zone'),prof2_1.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,0].set_ylabel('Percent of Mass')
axs[0,0].set_xlabel('Zone')
axs[0,0].set_ylim(-.05,1.05)
axs[0,0].set_xlim(np.max(prof2_1.data('zone'))+10,np.min(prof2_1.data('zone'))-10)
axs[0,0].set_title('Profile 1 Zones v Elemental Mass %')
axs[0,0].legend()

axs[0,1].plot(prof2_2.data('zone'),prof2_2.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,1].plot(prof2_2.data('zone'),prof2_2.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,1].plot(prof2_2.data('zone'),prof2_2.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,1].set_ylabel('Percent of Mass')
axs[0,1].set_xlabel('Zone')
axs[0,1].set_ylim(-.05,1.05)
axs[0,1].set_xlim(np.max(prof2_2.data('zone'))+10,np.min(prof2_2.data('zone'))-10)
axs[0,1].set_title('Profile 2 Zones v Elemental Mass %')
axs[0,1].legend()

axs[0,2].plot(prof2_3.data('zone'),prof2_3.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,2].plot(prof2_3.data('zone'),prof2_3.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,2].plot(prof2_3.data('zone'),prof2_3.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,2].set_ylabel('Percent of Mass')
axs[0,2].set_xlabel('Zone')
axs[0,2].set_ylim(-.05,1.05)
axs[0,2].set_xlim(np.max(prof2_3.data('zone'))+10,np.min(prof2_3.data('zone'))-10)
axs[0,2].set_title('Profile 3 Zones v Elemental Mass %')
axs[0,2].legend()

axs[1,0].plot(prof2_4.data('zone'),prof2_4.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,0].plot(prof2_4.data('zone'),prof2_4.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,0].plot(prof2_4.data('zone'),prof2_4.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,0].set_ylabel('Percent of Mass')
axs[1,0].set_xlabel('Zone')
axs[1,0].set_ylim(-.05,1.05)
axs[1,0].set_xlim(np.max(prof2_4.data('zone'))+10,np.min(prof2_4.data('zone'))-10)
axs[1,0].set_title('Profile 4 Zones v Elemental Mass %')
axs[1,0].legend()

axs[1,1].plot(prof2_5.data('zone'),prof2_5.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,1].plot(prof2_5.data('zone'),prof2_5.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,1].plot(prof2_5.data('zone'),prof2_5.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,1].set_ylabel('Percent of Mass')
axs[1,1].set_xlabel('Zone')
axs[1,1].set_ylim(-.05,1.05)
axs[1,1].set_xlim(np.max(prof2_5.data('zone'))+10,np.min(prof2_5.data('zone'))-10)
axs[1,1].set_title('Profile 5 Zones v Elemental Mass %')
axs[1,1].legend()

axs[1,2].plot(prof2_6.data('zone'),prof2_6.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,2].plot(prof2_6.data('zone'),prof2_6.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,2].plot(prof2_6.data('zone'),prof2_6.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,2].set_ylabel('Percent of Mass')
axs[1,2].set_xlabel('Zone')
axs[1,2].set_ylim(-.05,1.05)
axs[1,2].set_xlim(np.max(prof2_6.data('zone'))+10,np.min(prof2_6.data('zone'))-10)
axs[1,2].set_title('Profile 6 Zones v Elemental Mass %')
axs[1,2].legend()

axs[2,0].plot(prof2_7.data('zone'),prof2_7.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[2,0].plot(prof2_7.data('zone'),prof2_7.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[2,0].plot(prof2_7.data('zone'),prof2_7.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[2,0].set_ylabel('Percent of Mass')
axs[2,0].set_xlabel('Zone')
axs[2,0].set_ylim(-.05,1.05)
axs[2,0].set_xlim(np.max(prof2_7.data('zone'))+10,np.min(prof2_7.data('zone'))-10)
axs[2,0].set_title('Profile 7 Zones v Elemental Mass %')
axs[2,0].legend()

axs[2,1].plot(prof2_8.data('zone'),prof2_8.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[2,1].plot(prof2_8.data('zone'),prof2_8.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[2,1].plot(prof2_8.data('zone'),prof2_8.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[2,1].set_ylabel('Percent of Mass')
axs[2,1].set_xlabel('Zone')
axs[2,1].set_ylim(-.05,1.05)
axs[2,1].set_xlim(np.max(prof2_8.data('zone'))+10,np.min(prof2_8.data('zone'))-10)
axs[2,1].set_title('Profile 8 Zones v Elemental Mass %')
axs[2,1].legend()

# %%
fig, axs = plt.subplots(5, 3, figsize=(16, 25))
plt.subplots_adjust(hspace=.25, wspace=0.25)

axs[0,0].plot(prof4_1.data('zone'),prof4_1.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,0].plot(prof4_1.data('zone'),prof4_1.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,0].plot(prof4_1.data('zone'),prof4_1.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,0].set_ylabel('Percent of Mass')
axs[0,0].set_xlabel('Zone')
axs[0,0].set_ylim(-.05,1.05)
axs[0,0].set_xlim(np.max(prof4_1.data('zone'))+10,np.min(prof4_1.data('zone'))-10)
axs[0,0].set_title('Profile 1 Zones v Elemental Mass %')
axs[0,0].legend()

axs[0,1].plot(prof4_2.data('zone'),prof4_2.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,1].plot(prof4_2.data('zone'),prof4_2.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,1].plot(prof4_2.data('zone'),prof4_2.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,1].set_ylabel('Percent of Mass')
axs[0,1].set_xlabel('Zone')
axs[0,1].set_ylim(-.05,1.05)
axs[0,1].set_xlim(np.max(prof4_2.data('zone'))+10,np.min(prof4_2.data('zone'))-10)
axs[0,1].set_title('Profile 2 Zones v Elemental Mass %')
axs[0,1].legend()

axs[0,2].plot(prof4_3.data('zone'),prof4_3.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[0,2].plot(prof4_3.data('zone'),prof4_3.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[0,2].plot(prof4_3.data('zone'),prof4_3.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[0,2].set_ylabel('Percent of Mass')
axs[0,2].set_xlabel('Zone')
axs[0,2].set_ylim(-.05,1.05)
axs[0,2].set_xlim(np.max(prof4_3.data('zone'))+10,np.min(prof4_3.data('zone'))-10)
axs[0,2].set_title('Profile 3 Zones v Elemental Mass %')
axs[0,2].legend()

axs[1,0].plot(prof4_4.data('zone'),prof4_4.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,0].plot(prof4_4.data('zone'),prof4_4.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,0].plot(prof4_4.data('zone'),prof4_4.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,0].set_ylabel('Percent of Mass')
axs[1,0].set_xlabel('Zone')
axs[1,0].set_ylim(-.05,1.05)
axs[1,0].set_xlim(np.max(prof4_4.data('zone'))+10,np.min(prof4_4.data('zone'))-10)
axs[1,0].set_title('Profile 4 Zones v Elemental Mass %')
axs[1,0].legend()

axs[1,1].plot(prof4_5.data('zone'),prof4_5.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,1].plot(prof4_5.data('zone'),prof4_5.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,1].plot(prof4_5.data('zone'),prof4_5.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,1].set_ylabel('Percent of Mass')
axs[1,1].set_xlabel('Zone')
axs[1,1].set_ylim(-.05,1.05)
axs[1,1].set_xlim(np.max(prof4_5.data('zone'))+10,np.min(prof4_5.data('zone'))-10)
axs[1,1].set_title('Profile 5 Zones v Elemental Mass %')
axs[1,1].legend()

axs[1,2].plot(prof4_6.data('zone'),prof4_6.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[1,2].plot(prof4_6.data('zone'),prof4_6.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[1,2].plot(prof4_6.data('zone'),prof4_6.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[1,2].set_ylabel('Percent of Mass')
axs[1,2].set_xlabel('Zone')
axs[1,2].set_ylim(-.05,1.05)
axs[1,2].set_xlim(np.max(prof4_6.data('zone'))+10,np.min(prof4_6.data('zone'))-10)
axs[1,2].set_title('Profile 6 Zones v Elemental Mass %')
axs[1,2].legend()

axs[2,0].plot(prof4_7.data('zone'),prof4_7.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[2,0].plot(prof4_7.data('zone'),prof4_7.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[2,0].plot(prof4_7.data('zone'),prof4_7.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[2,0].set_ylabel('Percent of Mass')
axs[2,0].set_xlabel('Zone')
axs[2,0].set_ylim(-.05,1.05)
axs[2,0].set_xlim(np.max(prof4_7.data('zone'))+10,np.min(prof4_7.data('zone'))-10)
axs[2,0].set_title('Profile 7 Zones v Elemental Mass %')
axs[2,0].legend()

axs[2,1].plot(prof4_8.data('zone'),prof4_8.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[2,1].plot(prof4_8.data('zone'),prof4_8.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[2,1].plot(prof4_8.data('zone'),prof4_8.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[2,1].set_ylabel('Percent of Mass')
axs[2,1].set_xlabel('Zone')
axs[2,1].set_ylim(-.05,1.05)
axs[2,1].set_xlim(np.max(prof4_8.data('zone'))+10,np.min(prof4_8.data('zone'))-10)
axs[2,1].set_title('Profile 8 Zones v Elemental Mass %')
axs[2,1].legend()

axs[2,2].plot(prof4_9.data('zone'),prof4_9.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[2,2].plot(prof4_9.data('zone'),prof4_9.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[2,2].plot(prof4_9.data('zone'),prof4_9.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[2,2].set_ylabel('Percent of Mass')
axs[2,2].set_xlabel('Zone')
axs[2,2].set_ylim(-.05,1.05)
axs[2,2].set_xlim(np.max(prof4_9.data('zone'))+10,np.min(prof4_9.data('zone'))-10)
axs[2,2].set_title('Profile 9 Zones v Elemental Mass %')
axs[2,2].legend()

axs[3,0].plot(prof4_10.data('zone'),prof4_10.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[3,0].plot(prof4_10.data('zone'),prof4_10.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[3,0].plot(prof4_10.data('zone'),prof4_10.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[3,0].set_ylabel('Percent of Mass')
axs[3,0].set_xlabel('Zone')
axs[3,0].set_ylim(-.05,1.05)
axs[3,0].set_xlim(np.max(prof4_10.data('zone'))+10,np.min(prof4_10.data('zone'))-10)
axs[3,0].set_title('Profile 10 Zones v Elemental Mass %')
axs[3,0].legend()

axs[3,1].plot(prof4_11.data('zone'),prof4_11.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[3,1].plot(prof4_11.data('zone'),prof4_11.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[3,1].plot(prof4_11.data('zone'),prof4_11.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[3,1].set_ylabel('Percent of Mass')
axs[3,1].set_xlabel('Zone')
axs[3,1].set_ylim(-.05,1.05)
axs[3,1].set_xlim(np.max(prof4_11.data('zone'))+10,np.min(prof4_11.data('zone'))-10)
axs[3,1].set_title('Profile 11 Zones v Elemental Mass %')
axs[3,1].legend()

axs[3,2].plot(prof4_12.data('zone'),prof4_12.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[3,2].plot(prof4_12.data('zone'),prof4_12.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[3,2].plot(prof4_12.data('zone'),prof4_12.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[3,2].set_ylabel('Percent of Mass')
axs[3,2].set_xlabel('Zone')
axs[3,2].set_ylim(-.05,1.05)
axs[3,2].set_xlim(np.max(prof4_12.data('zone'))+10,np.min(prof4_12.data('zone'))-10)
axs[3,2].set_title('Profile 12 Zones v Elemental Mass %')
axs[3,2].legend()

axs[4,0].plot(prof4_13.data('zone'),prof4_13.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[4,0].plot(prof4_13.data('zone'),prof4_13.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[4,0].plot(prof4_13.data('zone'),prof4_13.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[4,0].set_ylabel('Percent of Mass')
axs[4,0].set_xlabel('Zone')
axs[4,0].set_ylim(-.05,1.05)
axs[4,0].set_xlim(np.max(prof4_13.data('zone'))+10,np.min(prof4_13.data('zone'))-10)
axs[4,0].set_title('Profile 13 Zones v Elemental Mass %')
axs[4,0].legend()

axs[4,1].plot(prof4_14.data('zone'),prof4_14.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[4,1].plot(prof4_14.data('zone'),prof4_14.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[4,1].plot(prof4_14.data('zone'),prof4_14.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[4,1].set_ylabel('Percent of Mass')
axs[4,1].set_xlabel('Zone')
axs[4,1].set_ylim(-.05,1.05)
axs[4,1].set_xlim(np.max(prof4_14.data('zone'))+10,np.min(prof4_14.data('zone'))-10)
axs[4,1].set_title('Profile 14 Zones v Elemental Mass %')
axs[4,1].legend()

axs[4,2].plot(prof4_15.data('zone'),prof4_15.data('x_mass_fraction_H'), c='violet', label='Hydrogen')
axs[4,2].plot(prof4_15.data('zone'),prof4_15.data('y_mass_fraction_He'), c='blue', label='Helium')
axs[4,2].plot(prof4_15.data('zone'),prof4_15.data('z_mass_fraction_metals'), c='green', label='Metals')
axs[4,2].set_ylabel('Percent of Mass')
axs[4,2].set_xlabel('Zone')
axs[4,2].set_ylim(-.05,1.05)
axs[4,2].set_xlim(np.max(prof4_15.data('zone'))+10,np.min(prof4_15.data('zone'))-10)
axs[4,2].set_title('Profile 15 Zones v Elemental Mass %')
axs[4,2].legend()

# %%
plt.plot(prof0_1.data('zone'),prof0_1.data('omega_div_omega_crit'), label='1', linewidth=2.5)
plt.plot(prof0_2.data('zone'),prof0_2.data('omega_div_omega_crit'), label='2', linewidth=2.5)
plt.plot(prof0_3.data('zone'),prof0_3.data('omega_div_omega_crit'), label='3', linewidth=2.5)
plt.plot(prof0_4.data('zone'),prof0_4.data('omega_div_omega_crit'), label='4', linewidth=2.5)
plt.plot(prof0_5.data('zone'),prof0_5.data('omega_div_omega_crit'), label='5', linewidth=2.5)
plt.plot(prof0_6.data('zone'),prof0_6.data('omega_div_omega_crit'), label='6', linewidth=2.5)
plt.axhline(y=1, linewidth=2.5, linestyle='--')
plt.xlabel('Zones')
plt.ylabel('$\Omega/\Omega_{crit}$')
plt.gca().invert_xaxis()
plt.title('0.0 $\Omega/\Omega_{crit}$ Profiles')
plt.legend()

# %%
plt.plot(prof2_1.data('zone'),prof2_1.data('omega_div_omega_crit'), label='1', linewidth=2.5)
plt.plot(prof2_2.data('zone'),prof2_2.data('omega_div_omega_crit'), label='2', linewidth=2.5)
plt.plot(prof2_3.data('zone'),prof2_3.data('omega_div_omega_crit'), label='3', linewidth=2.5)
plt.plot(prof2_4.data('zone'),prof2_4.data('omega_div_omega_crit'), label='4', linewidth=2.5)
plt.plot(prof2_5.data('zone'),prof2_5.data('omega_div_omega_crit'), label='5', linewidth=2.5)
plt.plot(prof2_6.data('zone'),prof2_6.data('omega_div_omega_crit'), label='6', linewidth=2.5)
plt.plot(prof2_7.data('zone'),prof2_7.data('omega_div_omega_crit'), label='7', linewidth=2.5)
plt.plot(prof2_8.data('zone'),prof2_8.data('omega_div_omega_crit'), label='8', linewidth=2.5)
plt.axhline(y=1, linewidth=2.5, linestyle='--')
plt.xlabel('Zones')
plt.ylabel('$\Omega/\Omega_{crit}$')
plt.gca().invert_xaxis()
plt.title('0.2 $\Omega/\Omega_{crit}$ Profiles')
plt.legend()

# %%
plt.plot(prof4_1.data('zone'),prof4_1.data('omega_div_omega_crit'), label='1', linewidth=2.5)
plt.plot(prof4_2.data('zone'),prof4_2.data('omega_div_omega_crit'), label='2', linewidth=2.5)
plt.plot(prof4_3.data('zone'),prof4_3.data('omega_div_omega_crit'), label='3', linewidth=2.5)
plt.plot(prof4_4.data('zone'),prof4_4.data('omega_div_omega_crit'), label='4', linewidth=2.5)
plt.plot(prof4_5.data('zone'),prof4_5.data('omega_div_omega_crit'), label='5', linewidth=2.5)
plt.plot(prof4_6.data('zone'),prof4_6.data('omega_div_omega_crit'), label='6', linewidth=2.5)
plt.plot(prof4_7.data('zone'),prof4_7.data('omega_div_omega_crit'), label='7', linewidth=2.5)
plt.plot(prof4_8.data('zone'),prof4_8.data('omega_div_omega_crit'), label='8', linewidth=2.5)
plt.plot(prof4_9.data('zone'),prof4_9.data('omega_div_omega_crit'), label='9', linewidth=2.5)
plt.plot(prof4_10.data('zone'),prof4_10.data('omega_div_omega_crit'), label='10', linewidth=2.5)
plt.plot(prof4_11.data('zone'),prof4_11.data('omega_div_omega_crit'), label='11', linewidth=2.5)
plt.plot(prof4_12.data('zone'),prof4_12.data('omega_div_omega_crit'), label='12', linewidth=2.5)
plt.plot(prof4_13.data('zone'),prof4_13.data('omega_div_omega_crit'), label='13', linewidth=2.5)
plt.plot(prof4_14.data('zone'),prof4_14.data('omega_div_omega_crit'), label='14', linewidth=2.5)
plt.plot(prof4_15.data('zone'),prof4_15.data('omega_div_omega_crit'), label='15', linewidth=2.5)
plt.axhline(y=1, linewidth=2.5, linestyle='--')
plt.xlabel('Zones')
plt.ylabel('$\Omega/\Omega_{crit}$')
plt.gca().invert_xaxis()
plt.title('0.4 $\Omega/\Omega_{crit}$ Profiles')
plt.legend()
